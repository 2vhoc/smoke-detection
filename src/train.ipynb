# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/GG Colab/YOLOv8
# Out:
# /content/drive/MyDrive/GG Colab/YOLOv8

# %%
pwd
# Out:
# '/content/drive/MyDrive/GG Colab/YOLOv8'

# %%
cd Datasets/
# Out:
# /content/drive/MyDrive/GG Colab/YOLOv8/Datasets

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.6/911.6 kB 36.8 MB/s eta 0:00:00
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO



model = YOLO("yolo11m.pt")

train_results = model.train(
    data="/content/drive/MyDrive/GG Colab/YOLOv8/Datasets/data.yaml",
    imgsz=640,
    device="cuda",
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()

results = model("/content/drive/MyDrive/GG Colab/YOLOv8/Datasets/test/images/ck0kmftzekfwv0a46aj0nh5dz_jpeg.rf.a9f20064706442166518aaa4f5274d5a.jpg")
results[0].show()

# path = model.export(format="onnx")
# Out:
# Ultralytics 8.3.65 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/GG Colab/YOLOv8/Datasets/valid/labels.cache... 147 images, 0 backgrounds, 0 corrupt: 100%|██████████| 147/147 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.90it/s]
#                    all        147        147      0.895       0.87      0.923      0.537
# Speed: 0.2ms preprocess, 20.7ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to runs/detect/train25
#
# image 1/1 /content/drive/MyDrive/GG Colab/YOLOv8/Datasets/test/images/ck0kmftzekfwv0a46aj0nh5dz_jpeg.rf.a9f20064706442166518aaa4f5274d5a.jpg: 480x640 1 smoke, 33.3ms
# Speed: 2.7ms preprocess, 33.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=640x480>
